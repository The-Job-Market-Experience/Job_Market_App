# %%
import pandas as pd

# %%
df = pd.read_csv('jobs.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                        job_titles  \
# 0           0          IT-Support-Mitarbeiter * 2nd & 3rd Level
# 1           1                 (Senior) Internal Auditor (f/m/d)
# 2           2         Continuous Improvement Specialist (m/w/d)
# 3           3  Regional Tax Manager - Germany, Netherlands & UK
# 4           4       CIO – Mitglied der Geschäftsleitung (m/w/d)
#
#                                          companies  \
# 0  valantic Software & Technology Innovations GmbH
# 1                          Heidelberg Materials AG
# 2                                Eaton Corporation
# 3                 ADM EMEA Corporate Services GmbH
# 4                    Sherman Silversteijn & Cie AG
#
#                                            locations  \
# 0  ['Eschborn bei Frankfurt', 'Feste Anstellung',...
# 1  ['Heidelberg, Germany', 'Erschienen: vor 16 St...
# 2  ['Mülheim an der Ruhr', 'Feste Anstellung', 'V...
# 3  ['Hamburg, Heidelberg', 'Feste Anstellung', 'V...
# 4  ['Nordrhein-Westfalen', 'Feste Anstellung', 'V...
#
#                                   description_titles  \
# 0  ['Einleitung', 'Ihre Aufgaben', 'Ihr Profil', ...
# 1  ['Heidelberg Materials – Material to build you...
# 2  ['Einleitung', 'Ihre Aufgaben', 'Ihr Profil', ...
# 3  ['Join our team at our Hamburg location', 'You...
# 4  ['Ihre Aufgabenschwerpunkte im Einzelnen:', 'I...
#
#                                         descriptions  \
# 0  ['Die valantic Software & Technology Innovatio...
# 1  ["Heidelberg Materials is one of the world's l...
# 2  ['Global Energy Infrastructure Solutions (GEIS...
# 3  ['ADM unlocks the power of nature to enrich th...
# 4  ['Die Sherman Silversteijn & Cie. AG bedient K...
#
#                                             benefits     time_of_scraping  \
# 0                                      not available  01/11/2023 11:27:11
# 1                                      not available  01/11/2023 11:27:11
# 2  ['Vorsorgeuntersuchungen', 'Betriebliche Alter...  01/11/2023 11:27:11
# 3                                      not available  01/11/2023 11:27:11
# 4                                      not available  01/11/2023 11:27:11
#
#        null
# 0  ['', '']
# 1  ['', '']
# 2  ['', '']
# 3  ['', '']
# 4  ['', '']

# %%
columns_to_drop = ['Unnamed: 0', 'null']
columns_to_drop = [col for col in columns_to_drop if col in df.columns]

# %%
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#                                          job_titles  \
# 0          IT-Support-Mitarbeiter * 2nd & 3rd Level
# 1                 (Senior) Internal Auditor (f/m/d)
# 2         Continuous Improvement Specialist (m/w/d)
# 3  Regional Tax Manager - Germany, Netherlands & UK
# 4       CIO – Mitglied der Geschäftsleitung (m/w/d)
#
#                                          companies  \
# 0  valantic Software & Technology Innovations GmbH
# 1                          Heidelberg Materials AG
# 2                                Eaton Corporation
# 3                 ADM EMEA Corporate Services GmbH
# 4                    Sherman Silversteijn & Cie AG
#
#                                            locations  \
# 0  ['Eschborn bei Frankfurt', 'Feste Anstellung',...
# 1  ['Heidelberg, Germany', 'Erschienen: vor 16 St...
# 2  ['Mülheim an der Ruhr', 'Feste Anstellung', 'V...
# 3  ['Hamburg, Heidelberg', 'Feste Anstellung', 'V...
# 4  ['Nordrhein-Westfalen', 'Feste Anstellung', 'V...
#
#                                   description_titles  \
# 0  ['Einleitung', 'Ihre Aufgaben', 'Ihr Profil', ...
# 1  ['Heidelberg Materials – Material to build you...
# 2  ['Einleitung', 'Ihre Aufgaben', 'Ihr Profil', ...
# 3  ['Join our team at our Hamburg location', 'You...
# 4  ['Ihre Aufgabenschwerpunkte im Einzelnen:', 'I...
#
#                                         descriptions  \
# 0  ['Die valantic Software & Technology Innovatio...
# 1  ["Heidelberg Materials is one of the world's l...
# 2  ['Global Energy Infrastructure Solutions (GEIS...
# 3  ['ADM unlocks the power of nature to enrich th...
# 4  ['Die Sherman Silversteijn & Cie. AG bedient K...
#
#                                             benefits     time_of_scraping
# 0                                      not available  01/11/2023 11:27:11
# 1                                      not available  01/11/2023 11:27:11
# 2  ['Vorsorgeuntersuchungen', 'Betriebliche Alter...  01/11/2023 11:27:11
# 3                                      not available  01/11/2023 11:27:11
# 4                                      not available  01/11/2023 11:27:11

# %%
df.dtypes
# Out:
# job_titles            object
# companies             object
# locations             object
# description_titles    object
# descriptions          object
# benefits              object
# time_of_scraping      object
# dtype: object

# %%
### import libraries

from bs4 import BeautifulSoup as bs
import requests
from urllib.parse import urljoin
import pandas as pd
import numpy as np

import datetime

import json

### get current time

now = datetime.datetime.now()

# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("the scraping starts at:", dt_string)

######################################################################

### request html code
### english language, data and germany. otherwise no parameter, sorted by publish date


url = 'https://www.stepstone.de/jobs/data/in-germany?radius=30&sort=2&action=sort_publish'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:39.0)'}

response = requests.get(url, headers=headers)

## status print
print("the get request:", response)

### parse response with beautiful soup

soup = bs(response.content, 'html.parser')

### status print

print("created the beautiful soup for:", soup.title)

## find and extract links to job offers

job_offer_links = []
links = soup.find_all("a", class_="res-y456gn")
base_url = 'https://www.stepstone.de'

for link in links:
    job_url = link.get('href')
    complete_job_url = urljoin(base_url, job_url)
    job_offer_links.append(complete_job_url)
    
print(len(job_offer_links), "new job offers found.")
###############################################################################

## parse and scrape from each job offer page
job_titles, companies, locations, anouncement_date, vollzeit, contract_type = [],[],[],[],[],[]
description_titles, descriptions, benefits = [],[],[]

for job_link in job_offer_links:
    print("scraping following job post:", job_link)
    job_response = requests.get(job_link, headers = headers)
    print("request status:", job_response.status_code)
    
    job_soup = bs(job_response.text, 'html.parser')
    
    job_title = job_soup.find('span', class_='listing-content-provider-bewwo')
    job_titles.append(job_title.text)
    
    company = job_soup.find('a', class_='listing-content-provider-zw6cpm')
    
    location_elements = job_soup.find_all('span', class_='listing-content-provider-1whr5zf')
    # I added to choose first element
    # location_elements = location_elements[0] I am creating if

    if location_elements:
        # if Sei einer der ersten Bewerber then skip to next element
        if "Sei einer der ersten Bewerber" in location_elements[0]:
            location_text = location_elements[1]
        else:
            location_text = location_elements[0]
    else:
        location_text = 'No info about location'
    

#  this is html :<a class="listing-content-provider-1ukm0vf" data-genesis-element="BASE" href="#location"><span class="listing-content-provider-uxgcen" data-genesis-element="ICON_CONTAINER"><svg aria-hidden="true" role="img" xmlns="http://www.w3.org/2000/svg" width="100%" height="100%" fill="none" viewBox="0 0 20 20" aria-labelledby="MapMarkerIcon-4"><title id="MapMarkerIcon-4">Map marker icon</title><path fill="currentColor" d="M9.998 9.833c.417 0 .77-.146 1.062-.437.292-.292.438-.646.438-1.063 0-.417-.146-.77-.438-1.062a1.444 1.444 0 00-1.062-.438c-.417 0-.77.146-1.062.438a1.444 1.444 0 00-.438 1.062c0 .417.146.771.438 1.063.291.291.645.437 1.062.437zm0 6.542c1.708-1.514 2.99-2.955 3.844-4.323.854-1.368 1.281-2.552 1.281-3.552 0-1.583-.493-2.861-1.479-3.833-.986-.973-2.201-1.459-3.646-1.459-1.445 0-2.66.486-3.646 1.459-.986.972-1.479 2.25-1.479 3.833 0 1 .427 2.184 1.281 3.552.855 1.368 2.136 2.809 3.844 4.323zm0 1.458a.967.967 0 01-.604-.187c-1.972-1.805-3.44-3.462-4.406-4.969C4.023 11.17 3.54 9.778 3.54 8.5c0-2.028.646-3.639 1.937-4.833 1.292-1.195 2.799-1.792 4.521-1.792s3.229.597 4.521 1.792c1.291 1.194 1.937 2.805 1.937 4.833 0 1.278-.483 2.67-1.448 4.177-.965 1.507-2.434 3.164-4.406 4.969a.732.732 0 01-.281.146 1.266 1.266 0 01-.323.041z"></path></svg></span><span class="listing-content-provider-1whr5zf" data-genesis-element="TEXT">Köln, Hamburg</span></a>

# I added .encode('iso-8859-1').decode('utf-8')
    # location_elements_list = [location.text.encode('iso-8859-1').decode('utf-8', errors='replace') for location in location_elements]
    location_elements_list = [location.text for location in location_text]
    locations.append(location_elements_list)
    
    benefit = job_soup.find('h4', class_='listing-company-content-provider-1nsjzge listingHeaderColor')
    
    description_title_elements = job_soup.find_all('h4', class_='listing-content-provider-1t9vh2w listingHeaderColor')
    description_title_list = [element.text for element in description_title_elements]
    description_titles.append(description_title_list)
    description_elements = job_soup.find_all('span', class_='listing-content-provider-14ydav7')
    description_list = [element.text for element in description_elements]
    descriptions.append(description_list)
    
    #############################################################################  anouncment_date
    
    anouncment_date_elements = job_soup.find_all('span', class_='listing-content-provider-1whr5zf')
    # I added to choose first element
    # location_elements = location_elements[0] I am creating if

    anouncment_date_text = anouncment_date_elements[-1]
    anouncment_date_elements_list = [anouncment.text for anouncment in anouncment_date_text]
    anouncement_date.append(anouncment_date_elements_list)

    #############################################################################  vollzeit
    
    vollzeit_elements = job_soup.find_all('span', class_='listing-content-provider-1whr5zf')
    # I added to choose first element
    # location_elements = location_elements[0] I am creating if

    vollzeit_text = vollzeit_elements[-2]
    vollzeit_elements_list = [vollzeit.text for vollzeit in vollzeit_text]
    vollzeit.append(vollzeit_elements_list)

    ############################################################################# contract_type

    contract_type_elements = job_soup.find_all('span', class_='listing-content-provider-1whr5zf')
    # I added to choose first element
    # location_elements = location_elements[0] I am creating if

    contract_type_text = contract_type_elements[-2]
    contract_type_elements_list = [contract_type.text for contract_type in contract_type_text]
    contract_type.append(contract_type_elements_list)

    #############################################################################
    
    if company:
        companies.append(company.text)
    else:
        companies.append('not available')
        
    if benefit:
        benefit_elements = job_soup.find_all('span', class_='listing-company-content-provider-1mvot2o')
        benefit_list = [element.text for element in benefit_elements]
        benefits.append(benefit_list)
    else:
        benefits.append('not available')

#############################################################################



df_new=pd.DataFrame(list(zip(job_titles, companies, locations, anouncement_date, vollzeit, contract_type, description_titles, descriptions, benefits)), columns=['job_titles', 'companies', 'locations', 'anouncement_date', 'vollzeit', 'contract_type' , 'description_titles', 'descriptions', 'benefits'])

df_new['time_of_scraping'] = pd.Series([dt_string] * len(df_new))

### save dataframe into .csv    
#old_df = pd.read_csv('jobs.csv')
#jobs = pd.concat([old_df, df_new], ignore_index=True)
#jobs.to_csv('./jobs.csv')

## when initialized: #df_new.to_csv('./jobs.csv')

### status print
#print("the new file has", len(jobs), "entries")
# Out:
# the scraping starts at: 07/11/2023 14:57:26
# the get request: <Response [200]>
# created the beautiful soup for: <title>Data Jobs und Stellenangebote in Germany - 2023</title>
# 25 new job offers found.
# scraping following job post: https://www.stepstone.de/stellenangebote--Senior-Consultant-Manager-m-w-d-Intelligent-Process-Performance-Berlin-Frankfurt-am-Main-Hamburg-Koeln-Muenchen-Stuttgart-Capgemini-Invent--9820490-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Systemadministrator-Linux-Teamleiter-in-spe-m-w-d-Berlin-index-Internet-und-Mediaforschung-GmbH--10167545-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Risiko-und-Compliance-Spezialist-fuer-Serverbetriebssysteme-m-w-d-Karlsruhe-Muenster-Atruvia-AG--9699662-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Manager-im-Inhouse-Consulting-Unternehmensstrategie-m-w-d-Karlsruhe-Muenchen-Muenster-Atruvia-AG--8511597-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Principal-Project-Manager-Inhouse-Consulting-m-w-d-Karlsruhe-Muenchen-Muenster-Atruvia-AG--8525810-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--CRM-Data-Analyst-m-w-d-Hamburg-Hannover-Berlin-Stuttgart-Ulm-Muenchen-Volkswagen-Retail-Dienstleistungsgesellschaft-mbH--10167496-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Referentin-m-w-d-CRM-Hamburg-Hannover-Berlin-Stuttgart-Ulm-Muenchen-Volkswagen-Retail-Dienstleistungsgesellschaft-mbH--10167503-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Management-Consultant-Bankstrategie-m-w-d-Karlsruhe-Muenchen-Muenster-Atruvia-AG--9925603-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Responsible-AI-Consultant-f-m-x-Muenchen-ZEISS--10009599-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Sachbearbeiter-Payroll-Benefits-w-m-x-Muenchen-Berlin-Erfurt-Ettlingen-Frankfurt-a-M-Hamburg-Koeln-Rosenheim-Stuttgart-Wolfsburg-NTT-DATA-Deutschland-SE--10220747-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Vermoegenskundenberater-m-w-d-Heilbronn-HypoVereinsbank-Member-of-UniCredit--10167566-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Senior-Backend-Developer-C-w-m-d-Koeln-RTL-Technology-GmbH--10167631-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Produkt-Marketing-Spezialist-f-m-x-Oberkochen-Baden-Wuerttemberg-ZEISS--10009862-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Data-Scientist-Industry-4-0-m-f-x-Muenchen-Oberkochen-Baden-Wuerttemberg-ZEISS--9057327-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Risk-Data-Analyst-w-m-d-Teilzeit-oder-Vollzeit-Mainz-TARGOBANK--9351571-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Data-Scientist-mit-Fokus-auf-Erfahrungsanalysen-Hannover-Hannover-Rueck-SE--10220662-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Junior-Consultant-Prozessmanagement-und-digitale-Transformation-m-w-d-Duesseldorf-Frankfurt-am-Main-Hamburg-Leipzig-Muenchen-Berlin-Stuttgart-Walldorf-BearingPoint-GmbH--9548461-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Manager-Clinical-Data-Management-Solutions-Cambridge-Gaithersburg-Mainz-BioNTech-SE--10167329-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Data-Process-Manager-m-w-d-Massing-Mjamjam-Petfood-GmbH--10220972-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Software-Test-Engineer-Softwaretester-Testingenieur-m-w-d-Karlsruhe-ViGEM-GmbH--10167333-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Senior-Manager-all-genders-Mobility-Transportation-Ecosystem-Stuttgart-Muenchen-Hamburg-Berlin-Frankfurt-am-Main-Porsche-Consulting-GmbH--9284418-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Data-Engineer-Scientist-Flexibility-Trading-m-f-d-Muenchen-The-Mobility-House-GmbH--10220882-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Administrative-clerk-Bremen-Marketplace-Hub--10068599-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Customer-Service-Representative-DACH-Sindelfingen-Marketplace-Hub--10068270-inline.html
# request status: 200
# scraping following job post: https://www.stepstone.de/stellenangebote--Inhouse-Consultant-Master-Data-Manager-gn-Loeningen-Remmers-Gruppe-AG--10220527-inline.html
# request status: 200

# %%
df_new.head()
# Out:
#                                           job_titles  \
# 0  Senior Consultant / Manager (m/w/d) Intelligen...
# 1  Systemadministrator Linux / Teamleiter in spe ...
# 2  Risiko und Compliance Spezialist für Serverbet...
# 3  Manager im Inhouse Consulting - Unternehmensst...
# 4  Principal Project Manager Inhouse Consulting (...
#
#                                 companies  \
# 0                        Capgemini Invent
# 1  index Internet und Mediaforschung GmbH
# 2                              Atruvia AG
# 3                              Atruvia AG
# 4                              Atruvia AG
#
#                                            locations  \
# 0  [Berlin, Frankfurt am Main, Hamburg, Köln, Mün...
# 1                                           [Berlin]
# 2                               [Karlsruhe, Münster]
# 3                      [Karlsruhe, München, Münster]
# 4                      [Karlsruhe, München, Münster]
#
#               anouncement_date                         vollzeit  \
# 0  [Erschienen: vor 5 Stunden]                       [Vollzeit]
# 1  [Erschienen: vor 5 Stunden]                       [Vollzeit]
# 2  [Erschienen: vor 5 Stunden]  [Vollzeit, Home Office möglich]
# 3  [Erschienen: vor 5 Stunden]  [Vollzeit, Home Office möglich]
# 4  [Erschienen: vor 5 Stunden]  [Vollzeit, Home Office möglich]
#
#                      contract_type  \
# 0                       [Vollzeit]
# 1                       [Vollzeit]
# 2  [Vollzeit, Home Office möglich]
# 3  [Vollzeit, Home Office möglich]
# 4  [Vollzeit, Home Office möglich]
#
#                                   description_titles  \
# 0  [Get the future you want, Your skills & career...
# 1  [Einleitung, Ihre Aufgaben, Ihr Profil, Wir bi...
# 2  [Über Atruvia, Aufgaben mit Perspektiven, Pers...
# 3  [Über Atruvia, Aufgaben mit Perspektiven, Pers...
# 4  [Über Atruvia, Aufgaben mit Perspektiven, Pers...
#
#                                         descriptions  \
# 0  [Capgemini Invent ist die weltweite Beratungs­...
# 1  [Vielfalt, Innovation und Leidenschaft – dafür...
# 2  [Wir sind der Digitalisierungspartner der geno...
# 3  [Wir sind der Digitalisierungspartner der geno...
# 4  [Wir sind der Digitalisierungspartner der geno...
#
#                                             benefits     time_of_scraping
# 0  [Vorsorgeuntersuchungen, Sportaktivitäten, Fle...  07/11/2023 14:57:26
# 1                                      not available  07/11/2023 14:57:26
# 2                                      not available  07/11/2023 14:57:26
# 3                                      not available  07/11/2023 14:57:26
# 4                                      not available  07/11/2023 14:57:26

# %%
df_new.anouncement_date
# Out:
# 0      [Erschienen: vor 5 Stunden]
# 1      [Erschienen: vor 5 Stunden]
# 2      [Erschienen: vor 5 Stunden]
# 3      [Erschienen: vor 5 Stunden]
# 4      [Erschienen: vor 5 Stunden]
# 5      [Erschienen: vor 5 Stunden]
# 6      [Erschienen: vor 5 Stunden]
# 7      [Erschienen: vor 5 Stunden]
# 8      [Erschienen: vor 5 Stunden]
# 9      [Erschienen: vor 6 Stunden]
# 10     [Erschienen: vor 5 Stunden]
# 11     [Erschienen: vor 5 Stunden]
# 12     [Erschienen: vor 5 Stunden]
# 13     [Erschienen: vor 5 Stunden]
# 14     [Erschienen: vor 5 Stunden]
# 15     [Erschienen: vor 7 Stunden]
# 16     [Erschienen: vor 6 Stunden]
# 17    [Erschienen: vor 11 Stunden]
# 18     [Erschienen: vor 5 Stunden]
# 19     [Erschienen: vor 8 Stunden]
# 20     [Erschienen: vor 7 Stunden]
# 21     [Erschienen: vor 6 Stunden]
# 22    [Erschienen: vor 12 Stunden]
# 23    [Erschienen: vor 12 Stunden]
# 24    [Erschienen: vor 14 Stunden]
# Name: anouncement_date, dtype: object
